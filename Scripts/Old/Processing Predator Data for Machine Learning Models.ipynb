# %% [markdown]
# # Processing Predator Data for Machine Learning Models
# ## Erica Keklak | 2025-06-25 to present

# %%
# Import necessary libraries and packages

import pandas as pd
import geopandas as gpd

# Assign basic pathing so it's easier to import files

def makepath(x: str, y: str) -> str:
    return str('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/' + y + x + ' iNaturalist.csv')

# %%
# Read in all crustacean and arachnid predator data from iNaturalist

z = 'Arachnids and Crustaceans/'
agelenopsis = pd.read_csv(makepath('Agelenopsis sp Grass spiders/Agelenopsis sp', z))
araneus = pd.read_csv(makepath('Araneus sp Angulate and roundshouldered orbweavers/Araneus sp', z), dtype = {31: object})
crab = pd.read_csv(makepath('Callinectes sapidus Atlantic blue crab/Callinectes sapidus', z))
harvestman = pd.read_csv(makepath('Complex Leiobunum ventricosum Early-season group harvestmen/Leiobunum ventricosum', z))
crossopriza = pd.read_csv(makepath('Crossopriza sp Tailed daddy long-legs spiders/Crossopriza sp', z))
larinioides = pd.read_csv(makepath('Larinioides cornutus Furrow orbweaver/Larinioides cornutus', z))
leucauge = pd.read_csv(makepath('Leucauge venusta Orchard orbweaver/Leucauge venusta', z))
neoscona = pd.read_csv(makepath('Neoscona sp Spotted orbweavers/Neoscona sp', z), dtype = {31: object, 40: object})
paraphidippus = pd.read_csv(makepath('Paraphidippus aurantius Emerald jumping spider/Paraphidippus aurantius', z))
parasteatoda = pd.read_csv(makepath('Parasteatoda tepidariorum Common house spider/Parasteatoda tepidariorum', z))
phidippus_a = pd.read_csv(makepath('Phidippus audax Bold jumping spider/Phidippus audax', z))
phidippus_p = pd.read_csv(makepath('Phidippus putnami Putnam\'s jumping spider/Phidippus putnami', z))
platycryptus = pd.read_csv(makepath('Platycryptus undatus Tan jumping spider/Platycryptus undatus', z), dtype = {15: object, 31: object})
rabidosa = pd.read_csv(makepath('Rabidosa rabida Rabid wolf spider/Rabidosa rabida', z))
steatoda = pd.read_csv(makepath('Steatoda sp False widow spiders/Steatoda sp', z), dtype = {31: object})

# %%
# Read in all bird predator data from iNaturalist

z = 'Birds/'
aix = pd.read_csv(makepath('Aix sp Wood and Mandarin Ducks/Aix sp', z))
anas = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Birds/Anas sp Typical ducks/Anas sp iNaturalist Part 1.csv',
                   dtype = {15: object}
                  )
anas2 = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Birds/Anas sp Typical ducks/Anas sp iNaturalist Part 2.csv',
                    dtype = {15: object}
                   )
anas3 = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Birds/Anas sp Typical ducks/Anas sp iNaturalist Part 3.csv',
                    dtype = {15: object}
                   )
anas = anas.merge(anas2).merge(anas3)
aythya = pd.read_csv(makepath('Aythya sp Typical diving ducks/Aythya sp', z))
baeolophus = pd.read_csv(makepath('Baeolophus bicolor Tufted titmouse/Baeolophus bicolor', z))
bucephala = pd.read_csv(makepath('Bucephala sp Goldeneyes and bufflehead/Bucephala sp', z))
cairina = pd.read_csv(makepath('Cairina sp Muscovy ducks/Cairina sp', z)) 
cardinal = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Birds/Cardinalis cardinalis Northern cardinal/Cardinalis cardinalis iNaturalist Part 1.csv')
cardinal2 = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Birds/Cardinalis cardinalis Northern cardinal/Cardinalis cardinalis iNaturalist Part 2.csv')
cardinal = cardinal.merge(cardinal2)
clangula = pd.read_csv(makepath('Clangula hyemalis Long-tailed duck/Clangula hyemalis', z))
coccyzus_a = pd.read_csv(makepath('Coccyzus americanus Yellow-billed cuckoo/Coccyzus americanus', z))
coccyzus_e = pd.read_csv(makepath('Coccyzus erythropthalmus Black-billed cuckoo/Coccyzus erythropthalmus', z))
contopus = pd.read_csv(makepath('Contopus cooperi Olive-sided flycatcher/Contopus cooperi', z))
jay = pd.read_csv(makepath('Cyanocitta cristata Blue jay/Cyanocitta cristata', z))
dendrocygna = pd.read_csv(makepath('Dendrocygna sp Whistling ducks/Dendrocygna sp', z))
catbird = pd.read_csv(makepath('Dumetella carolinensis Gray catbird/Dumetella carolinensis', z))
kite = pd.read_csv(makepath('Elanoides forficatus Swallow-tailed kite/Elanoides forficatus', z))
chicken = pd.read_csv(makepath('Gallus gallus domesticus Domestic chicken/Gallus gallus domesticus', z))
histrionicus = pd.read_csv(makepath('Histrionicus histrionicus Harlequin duck/Histrionicus histrionicus', z))
oriole = pd.read_csv(makepath('Icterus galbula Baltimore oriole/Icterus galbula', z))
lophodytes = pd.read_csv(makepath('Lophodytes cucullatus Hooded merganser/Lophodytes cucullatus', z))
mareca = pd.read_csv(makepath('Mareca sp Wigeons/Mareca sp', z))
melanerpes_c = pd.read_csv(makepath('Melanerpes carolinus Red-bellied woodpecker/Melanerpes carolinus', z))
melanerpes_e = pd.read_csv(makepath('Melanerpes erythrocephalus Red-headed woodpecker/Melanerpes erythrocephalus', z))
melanitta = pd.read_csv(makepath('Melanitta sp Scoters/Melanitta sp', z), dtype = {15: object})
melospiza = pd.read_csv(makepath('Melospiza melodia Song sparrow/Melospiza melodia', z))
smew = pd.read_csv(makepath('Mergellus albellus Smew/Mergellus albellus', z))
mergus = pd.read_csv(makepath('Mergus sp Typical mergansers/Mergus sp', z), dtype = {15: object})
myiarchus = pd.read_csv(makepath('Myiarchus crinitus Great crested flycatcher/Myiarchus crinitus', z))
netta = pd.read_csv(makepath('Netta sp Dabbling pochards/Netta sp', z))
nomonyx = pd.read_csv(makepath('Nomonyx dominicus Masked duck/Nomonyx dominicus', z))
oxyura = pd.read_csv(makepath('Oxyura sp Stiff-tailed ducks/Oxyura sp', z))
poecile = pd.read_csv(makepath('Poecile carolinensis Carolina chickadee/Poecile carolinensis', z))
polioptila = pd.read_csv(makepath('Polioptila caerulea Blue-gray flycatcher/Polioptila caerulea', z))
somateria = pd.read_csv(makepath('Somateria sp Typical eiders/Somateria sp', z))
spatula = pd.read_csv(makepath('Spatula sp Scaups/Spatula sp', z))
kingbird = pd.read_csv(makepath('Tyrannus tyrannus Eastern kingbird/Tyrannus tyrannus', z))

# %%
# Read in all fish and herptile predator data from iNaturalist

z = 'Fish and Herptiles/'
goldfish = pd.read_csv(makepath('Carassius auratus Goldfish/Carassius auratus', z))
koi = pd.read_csv(makepath('Cyprinus rubrofuscus Amur carp/Cyprinus rubrofuscus', z))
lepomis = pd.read_csv(makepath('Lepomis cyanellus Green sunfish/Lepomis cyanellus', z))
frog = pd.read_csv(makepath('Lithobates clamitans Green frog/Lithobates clamitans', z))
snake = pd.read_csv(makepath('Thamnophis sp Garter snakes/Thamnophis sp', z), dtype = {15: object})

# %%
# Read in all insect predator data from iNaturalist

z = 'Insects/'
camponotus = pd.read_csv(makepath('Camponotus sp Carpenter ants/Camponotus sp', z), dtype = {31: object})
formica = pd.read_csv(makepath('Complex Formica pallidefulva Pallidefulva-group field ants/Formica pallidefulva', z))
monomorium = pd.read_csv(makepath('Complex Monomorium carbonarium Little black ants/Monomorium carbonarium', z))
solenopsis = pd.read_csv(makepath('Complex Solenopsis molesta Molesta-group thief ants/Solenopsis molesta', z))
hammertail = pd.read_csv(makepath('Efferia aestuans Northeastern hammertail/Efferia aestuans', z))
euthyrhynchus = pd.read_csv(makepath('Euthyrhynchus floridanus Florida predatory stink bug/Euthyrhynchus floridanus', z))
mantis = pd.read_csv(makepath('Mantodea Mantises/Mantodea', z), dtype = {15: object, 40: object})
nylanderia = pd.read_csv(makepath('Nylanderia flavipes Yellow-footed ant/Nylanderia flavipes', z))
podisus = pd.read_csv(makepath('Podisus maculieventris Spined soldier bug/Podisus maculieventris', z))
polistes = pd.read_csv(makepath('Polistes sp Paper wasps/Polistes sp', z), dtype = {31: object})
katydid = pd.read_csv(makepath('Pterophylla camellifolia Common true katydid/Pterophylla camellifolia', z))
reduviidae = pd.read_csv(makepath('Reduviidae Assassin bugs/Reduviidae', z), dtype = {15: object, 31: object})
cricket = pd.read_csv(makepath('Tachycines asynamorus Greenhouse camel cricket/Tachycines asynamorus', z))
tapinoma = pd.read_csv(makepath('Tapinoma sessile Odorous house ant/Tapinoma sessile', z))
tetramorium = pd.read_csv(makepath('Tetramorium immigrans Immigrant pavement ant/Tetramorium immigrans', z))
vespa = pd.read_csv(makepath('Vespa sp Hornets/Vespa sp', z))
vespula = pd.read_csv(makepath('Vespula sp Ground yellowjackets/Vespula sp', z), dtype = {15: object, 31: object})

# %%
# Read in all mammal predator data from iNaturalist

dog = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Mammals/Canis lupus familiaris Domestic dog/Canis lupus familiaris iNaturalist.csv') 
bat = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Mammals/Chiroptera Bats/Chiroptera iNaturalist.csv', dtype = {41: object})
cat = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Mammals/Felis catus Domestic cat/Felis catus iNaturalist.csv')
marmot = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Mammals/Marmotini Ground squirrels/Marmotini iNaturalist.csv', dtype = {40: object})
sciurus_ab = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Mammals/Sciurus aberti Abert\'s squirrel/Sciurus aberti iNaturalist.csv')
sciurus_az = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Mammals/Sciurus arizonensis Arizona gray squirrel/Sciurus arizonensis iNaturalist.csv')
sciurus_c = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Mammals/Sciurus carolinensis Eastern gray squirrel/Sciurus carolinensis iNaturalist.csv')
sciurus_g = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Mammals/Sciurus griseus Western gray squirrel/Sciurus griseus iNaturalist.csv')
sciurus_na = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Mammals/Sciurus nayaritensis Mexican fox squirrel/Sciurus nayaritensis iNaturalist.csv')
sciurus_ni = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Mammals/Sciurus niger Fox squirrel/Sciurus niger iNaturalist.csv')

# %%
# Create a dictionary of predator species so iterating through them in functions becomes easier

predators_dict = {'Agelenopsis sp.': agelenopsis, 'Aix sp.': aix, 'Anas sp.': anas, 'Araneus sp.': araneus, 'Aythya sp.': aythya, 'Baeolophus bicolor':
                  baeolophus, 'Bucephala sp.': bucephala, 'Cairina sp.': cairina, 'Callinectes sapidus': crab, 'Camponotus sp.': camponotus,
                  'Canis lupus familiaris': dog, 'Carassius auratus': goldfish, 'Cardinalis cardinalis': cardinal, 'Chiroptera': bat,
                  'Clangula hyemalis': clangula, 'Coccyzus americanus': coccyzus_a, 'Coccyzus erythropthalmus': coccyzus_e,
                  'Complex Formica pallidefulva': formica, 'Complex Leiobunum ventricosum': harvestman, 'Complex Monomorium carbonarium': monomorium,
                  'Complex Solenopsis molesta': solenopsis, 'Contopus cooperi': contopus, 'Crossopriza sp.': crossopriza, 'Cyanocitta cristata': jay,
                  'Cyprinus rubrofuscus': koi, 'Dendrocygna sp.': dendrocygna, 'Dumetella carolinensis': catbird, 'Efferia aestuans': hammertail,
                  'Elanoides forficatus': kite, 'Euthyrhynchus floridanus': euthyrhynchus, 'Felis catus': cat, 'Gallus gallus domesticus': chicken,
                  'Histrionicus histrionicus': histrionicus, 'Icterus galbula': oriole, 'Larinioides cornutus': larinioides, 'Lepomis cyanellus': lepomis,
                  'Leucauge venusta': leucauge, 'Lithobates clamitans': frog, 'Lophodytes cucullatus': lophodytes, 'Mantodea': mantis, 'Mareca sp.':
                  mareca, 'Marmotini': marmot, 'Melanerpes carolinus': melanerpes_c, 'Melanerpes erythrocephalus': melanerpes_e, 'Melanitta sp.':
                  melanitta, 'Melospiza melodia': melospiza, 'Mergellus albellus': smew, 'Mergus sp.': mergus, 'Myiarchus crinitus': myiarchus,
                  'Neoscona sp.': neoscona, 'Netta sp.': netta, 'Nomonyx dominicus': nomonyx, 'Nylanderia flavipes': nylanderia, 'Oxyura sp.': oxyura,
                  'Paraphidippus aurantius': paraphidippus, 'Parasteatoda tepidariorum': parasteatoda, 'Phidippus audax': phidippus_a, 'Phidippus putnami':
                  phidippus_p, 'Platycryptus undatus': platycryptus, 'Podisus maculieventris': podisus, 'Poecile carolinensis': poecile,
                  'Polioptila caerula': polioptila, 'Polistes sp.': polistes, 'Pterophylla camellifolia': katydid, 'Rabidosa rabida': rabidosa,
                  'Reduviidae': reduviidae, 'Sciurus aberti': sciurus_ab, 'Sciurus arizonensis': sciurus_az, 'Sciurus carolinensis': sciurus_c,
                  'Sciurus griseus': sciurus_g, 'Sciurus nayaritensis': sciurus_na, 'Sciurus niger': sciurus_ni, 'Somateria sp.': somateria, 'Spatula sp.':
                  spatula, 'Steatoda sp.': steatoda, 'Tachycines asynamorus': cricket, 'Tapinoma sessile': tapinoma, 'Tetramorium immigrans': tetramorium,
                  'Thamnophis sp.': snake, 'Tyrannus tyrannus': kingbird, 'Vespa sp.': vespa, 'Vespula sp.': vespula
                 }

predators_list = ['Agelenopsis sp.', 'Aix sp.', 'Anas sp.', 'Araneus sp.', 'Aythya sp.', 'Baeolophus bicolor', 'Bucephala sp.', 'Cairina sp.', 
                  'Callinectes sapidus', 'Camponotus sp.', 'Canis lupus familiaris', 'Carassius auratus', 'Cardinalis cardinalis', 'Chiroptera',
                  'Clangula hyemalis', 'Coccyzus americanus', 'Coccyzus erythropthalmus', 'Complex Formica pallidefulva', 'Complex Leiobunum ventricosum',
                  'Complex Monomorium carbonarium', 'Complex Solenopsis molesta', 'Contopus cooperi', 'Crossopriza sp.', 'Cyanocitta cristata',
                  'Cyprinus rubrofuscus', 'Dendrocygna sp.', 'Dumetella carolinensis', 'Efferia aestuans', 'Elanoides forficatus',
                  'Euthyrhynchus floridanus', 'Felis catus', 'Gallus gallus domesticus', 'Histrionicus histrionicus', 'Icterus galbula',
                  'Larinioides cornutus', 'Lepomis cyanellus', 'Leucauge venusta', 'Lithobates clamitans', 'Lophodytes cucullatus', 'Mantodea',
                  'Mareca sp.', 'Marmotini', 'Melanerpes carolinus', 'Melanerpes erythrocephalus', 'Melanitta sp.', 'Melospiza melodia',
                  'Mergellus albellus', 'Mergus sp.', 'Myiarchus crinitus', 'Neoscona sp.', 'Netta sp.', 'Nomonyx dominicus', 'Nylanderia flavipes',
                  'Oxyura sp.', 'Paraphidippus aurantius', 'Parasteatoda tepidariorum', 'Phidippus audax', 'Phidippus putnami', 'Platycryptus undatus',
                  'Podisus maculieventris', 'Poecile carolinensis', 'Polioptila caerula', 'Polistes sp.', 'Pterophylla camellifolia', 'Rabidosa rabida',
                  'Reduviidae', 'Sciurus aberti', 'Sciurus arizonensis', 'Sciurus carolinensis', 'Sciurus griseus', 'Sciurus nayaritensis',
                  'Sciurus niger', 'Somateria sp.', 'Spatula sp.', 'Steatoda sp.', 'Tachycines asynamorus', 'Tapinoma sessile', 'Tetramorium immigrans',
                  'Thamnophis sp.', 'Tyrannus tyrannus', 'Vespa sp.', 'Vespula sp.'
                 ]

# %%
agelenopsis.columns
# Out:
# Index(['id', 'uuid', 'observed_on_string', 'observed_on', 'time_observed_at',
#        'time_zone', 'user_id', 'user_login', 'user_name', 'created_at',
#        'updated_at', 'quality_grade', 'license', 'url', 'image_url',
#        'sound_url', 'tag_list', 'description', 'num_identification_agreements',
#        'num_identification_disagreements', 'captive_cultivated',
#        'oauth_application_id', 'place_guess', 'latitude', 'longitude',
#        'positional_accuracy', 'private_place_guess', 'private_latitude',
#        'private_longitude', 'public_positional_accuracy', 'geoprivacy',
#        'taxon_geoprivacy', 'coordinates_obscured', 'positioning_method',
#        'positioning_device', 'species_guess', 'scientific_name', 'common_name',
#        'iconic_taxon_name', 'taxon_id', 'field:quantity',
#        'field:quantity observed'],
#       dtype='object')

# %%
# Create a function that removes unimportant columns

def drop_specific(df: pd.DataFrame, columnlist: list) -> pd.DataFrame:
    return df.drop(columns = columnlist, axis = 1)

# %%
# Operate that function

for i in range(0, len(predators_list)):
    this_predator = predators_dict[predators_list[i]]
    this_predator = drop_specific(this_predator, ['id', 'observed_on_string', 'observed_on', 'user_id', 'user_login', 'user_name', 'created_at',
                                                  'updated_at', 'license', 'sound_url', 'tag_list', 'description', 'num_identification_agreements',
                                                  'num_identification_disagreements', 'captive_cultivated', 'oauth_application_id', 'place_guess',
                                                  'private_place_guess', 'geoprivacy', 'taxon_geoprivacy', 'coordinates_obscured', 'positioning_method',
                                                  'positioning_device', 'species_guess', 'scientific_name', 'common_name', 'iconic_taxon_name', 'taxon_id'
                                                 ]
                                 )

# %%
# Create a function that displays the unique values of certain columns to check whether or not they are important

def columns_of_frames(dflist: list, dfdict: dict):
    return [dfdict[df].columns for df in dflist]

# %%
# Operate that function

print(columns_of_frames(predators_list, predators_dict))
# Out:
# [Index(['id', 'uuid', 'observed_on_string', 'observed_on', 'time_observed_at',
#        'time_zone', 'user_id', 'user_login', 'user_name', 'created_at',
#        'updated_at', 'quality_grade', 'license', 'url', 'image_url',
#        'sound_url', 'tag_list', 'description', 'num_identification_agreements',
#        'num_identification_disagreements', 'captive_cultivated',
#        'oauth_application_id', 'place_guess', 'latitude', 'longitude',
#        'positional_accuracy', 'private_place_guess', 'private_latitude',
#        'private_longitude', 'public_positional_accuracy', 'geoprivacy',
#        'taxon_geoprivacy', 'coordinates_obscured', 'positioning_method',
#        'positioning_device', 'species_guess', 'scientific_name', 'common_name',
#        'iconic_taxon_name', 'taxon_id', 'field:quantity',
#        'field:quantity observed'],
#       dtype='object'), Index(['id', 'uuid', 'observed_on_string', 'observed_on', 'time_observed_at',
# ...

# %%
# Read every predator CSV

agelenopsis_sp_iNat = pd.read_csv('C:/Users/EK111/Documents/NJIT/Spotted Lanternfly Project URI Summer 2025/Raw Data Backups/Predator Ecological/Arachnids and Crustaceans/Agelenopsis sp Grass spiders/Agelenopsis sp iNaturalist.csv')

# Put them all into a list

predators = []

# Delete rows not needed but do it procedurally using a function

def remove_unnecessary_data(df: pd.DataFrame) -> pd.DataFrame
    # timestamp conversion needed on this line
    df = df.drop(df.loc[df['quality grade'] != 'research' or df['']], axis = 0) # find more and fix the columns dropped if they give lots of KeyErrors
    return df

# Select the best/most useful columns

# %%
# Remove more
